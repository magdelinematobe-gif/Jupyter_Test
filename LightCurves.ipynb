# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import math

# %%
import os
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from astropy import units as unt
from astropy import wcs
import astropy.io.ascii as ascii
from matplotlib import rc,rcParams
import astropy.visualization as viz
from astropy import constants as const
import matplotlib.gridspec as gridspec
from astropy.coordinates import SkyCoord
from astropy.table import Table, hstack, vstack
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 

import astropy.io.fits as fits
import matplotlib as mpl
# %matplotlib inline

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 24472/')

# %%
# read fits file
file = fits.open(os.path.join(data_dir,'24472.fits'))
file.info() # file information
file[0].header
# Out:
# Filename: /home/user/Desktop/TESS DATA/HD 24472/24472.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  LIGHTCURVE    1 BinTableHDU    167   18314R x 20C   [D, E, J, E, E, E, E, E, E, J, D, E, D, E, D, E, D, E, E, E]
#   2  APERTURE      1 ImageHDU        49   (11, 13)   int32
# SIMPLE  =                    T / conforms to FITS standards
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T / file contains extensions
# NEXTEND =                    2 / number of standard extensions
# EXTNAME = 'PRIMARY '           / name of extension
# EXTVER  =                    1 / extension version number (not format version)
# SIMDATA =                    F / file is based on simulated data
# ORIGIN  = 'NASA/Ames'          / institution responsible for creating this file
# DATE    = '2020-12-12'         / file creation date.
# ...

# %%
data = file[1].data
data
# Out:
# FITS_rec([(2144.5133146 , 0.00404137, 660279,       nan,       nan,       nan,       nan,       nan,       nan, 168, nan, nan, nan, nan,           nan,        nan,           nan,        nan,         nan,         nan),
#           (2144.51470353, 0.00404141, 660280,       nan,       nan,       nan,       nan,       nan,       nan,  32, nan, nan, nan, nan,           nan,        nan,           nan,        nan,         nan,         nan),
#           (2144.51609246, 0.00404146, 660281,       nan,       nan,       nan,       nan,       nan,       nan,  32, nan, nan, nan, nan,           nan,        nan,           nan,        nan,         nan,         nan),
#           ...,
#           (2169.94548358, 0.00427719, 678590, 310173.72, 59.787643, 3054.2056, 8.6823015, 319991.06, 61.64583 ,   0, nan, nan, nan, nan, 1240.17519788, 0.00018686, 2031.27371689, 0.00017324, -0.02091078, -0.01561254),
# ...

# %%
time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
#np.shape(flux)
#np.shape(flux1)

# %%
fig=plt.figure('a.pdf')
fig=plt.figure(figsize=(12,6))              #figsize=(12,6)
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 24472')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(310500, 311250)
#plt.xlim(2145, 2150)
plt.legend(loc='upper right')
plt.show

fig.savefig('a.pdf')

# %%
fig=plt.figure('a1.pdf')
fig=plt.figure(figsize=(12,6))              #figsize=(12,6)
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 24472')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(310500, 311250)
#plt.xlim(2145, 2150)
plt.legend(loc='upper right')
plt.show

fig.savefig('a1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 39421/')


# read fits file
file = fits.open(os.path.join(data_dir,'39421.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (41332,)

# %%
fig=plt.figure('b.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 39421')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('b.pdf')

# %%
fig=plt.figure('b1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 39421')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('b1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 81290/')


# read fits file
file = fits.open(os.path.join(data_dir,'81290.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18066,)

# %%
fig=plt.figure('c.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 81290')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('c.pdf')

# %%
fig=plt.figure('c1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 81290')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('c1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 83277/')


# read fits file
file = fits.open(os.path.join(data_dir,'83277.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (17997,)

# %%
fig=plt.figure('d.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 83277')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('d.pdf')

# %%
fig=plt.figure('d1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 83277')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
#plt.xlim(2256, 2260)
plt.legend(loc='upper right')
plt.show()
fig.savefig('d1.pdf')

# %%
fig=plt.figure('d2.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 83277')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.xlim(2255.6, 2267.5)
plt.legend(loc='upper right')
plt.show()
fig.savefig('d2.pdf')

# %%
fig=plt.figure('d3.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 83277')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.xlim(2271.9, 2280.2)
plt.legend(loc='upper right')
plt.show()
fig.savefig('d3.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 100546/')


# read fits file
file = fits.open(os.path.join(data_dir,'100546.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (19064,)

# %%
fig=plt.figure('e.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 100546')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('e.pdf')

# %%
fig=plt.figure('e1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 100546')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('e1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 102541/')


# read fits file
file = fits.open(os.path.join(data_dir,'102541.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18814,)

# %%
fig=plt.figure('f.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 102541')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('f.pdf')

# %%
fig=plt.figure('f1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 102541')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('f1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 111005/')


# read fits file
file = fits.open(os.path.join(data_dir,'111005.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18896,)

# %%
fig=plt.figure('g.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 111005')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('g.pdf')

# %%
fig=plt.figure('g1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 111005')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('g1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 125889/')


# read fits file
file = fits.open(os.path.join(data_dir,'125889.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (19226,)

# %%
fig=plt.figure('h.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 125889')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('h.pdf')

# %%
fig=plt.figure('h1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 125889')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('h1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 141569/')


# read fits file
file = fits.open(os.path.join(data_dir,'141569.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (17707,)

# %%
fig=plt.figure('i.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 141569')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('i.pdf')

# %%
fig=plt.figure('i1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 141569')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('i1.pdf')

# %%
# No TESS data for this particular star 
# where is the data located?
#cwd = os.getcwd()
#data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 149130/')


# read fits file
#file = fits.open(os.path.join(data_dir,'149130.fits'))
#file.info() # file information
#file[0].header
#data = file[1].data
#data

# %%
#time = data['TIME'] 
#flux = data['SAP_FLUX']
#np.shape(flux)

#fig=plt.figure('j.pdf')
#plt.figure()
#plt.scatter(time,flux, s=2, alpha=0.3, c="k", label='HD 149130')
#plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
#plt.xlabel("Time ([Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
#plt.legend(loc='upper right')
#plt.show()
#fig.savefig(j'.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 154153/')


# read fits file
file = fits.open(os.path.join(data_dir,'154153.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18862,)

# %%
fig=plt.figure('k.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 154153')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('k.pdf')

# %%
fig=plt.figure('k1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 154153')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('k1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 156954/')


# read fits file
file = fits.open(os.path.join(data_dir,'156954.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (19780,)

# %%
fig=plt.figure('l.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 156954')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500
#plt.xlim(3775.5, 3776)
plt.legend(loc='upper right')
plt.show()
fig.savefig('l.pdf')

# %%
fig=plt.figure('l1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 156954')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500
#plt.xlim(3775.5, 3776)
plt.legend(loc='upper right')
plt.show()
fig.savefig('l1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 183007/')


# read fits file
file = fits.open(os.path.join(data_dir,'183007.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18620,)

# %%
fig=plt.figure('m.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 183007')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('m.pdf')

# %%
fig=plt.figure('m1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 183007')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('m1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 193281/')


# read fits file
file = fits.open(os.path.join(data_dir,'193281.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18620,)

# %%
fig=plt.figure('n.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 193281')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('n.pdf')

# %%
fig=plt.figure('n1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 193281')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('n1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 213669/')


# read fits file
file = fits.open(os.path.join(data_dir,'213669.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18182,)

# %%
fig=plt.figure('o.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 213669')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
#lt.xlim(2065, 2070)
plt.legend(loc='upper right')
plt.show()
fig.savefig('o.pdf')

# %%
fig=plt.figure('o1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 213669')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
#lt.xlim(2065, 2070)
plt.legend(loc='upper right')
plt.show()
fig.savefig('o1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 216847/')


# read fits file
file = fits.open(os.path.join(data_dir,'216847.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18182,)

# %%
fig=plt.figure('p.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 216847')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('p.pdf')

# %%
fig=plt.figure('p1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 216847')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('p1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 220278/')


# read fits file
file = fits.open(os.path.join(data_dir,'220278.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18864,)

# %%
fig=plt.figure('q.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 220278')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('q.pdf')

# %%
fig=plt.figure('q1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 220278')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('q1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 223352/')


# read fits file
file = fits.open(os.path.join(data_dir,'223352.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18487,)

# %%
fig=plt.figure('r.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 223352')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
 #plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('r.pdf')

# %%
fig=plt.figure('r1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 223352')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
 #plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('r1.pdf')

# %%
# where is the data located?
cwd = os.getcwd()
data_dir = os.path.join(cwd, '/home/user/Desktop/TESS DATA/HD 261904/')


# read fits file
file = fits.open(os.path.join(data_dir,'261904.fits'))
#file.info() # file information
#file[0].header
data = file[1].data
#data

time = data['TIME'] 
flux = data['SAP_FLUX']
flux1 = data['PDCSAP_FLUX']
np.shape(flux)
# Out:
# (18609,)

# %%
fig=plt.figure('s.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux, s=2, alpha=1, c="maroon", label='HD 261904')
plt.ylabel("SAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('s.pdf')

# %%
fig=plt.figure('s1.pdf')
fig=plt.figure(figsize=(12,6))
plt.scatter(time,flux1, s=2, alpha=1, c="maroon", label='HD 261904')
plt.ylabel("PDCSAP_Flux [$e^{-}s^{-1}$]") # Simple aperture photometry flux (e-/s)
plt.xlabel("Time [Barycentric TESS Julian Date - 2457000]")
#plt.ylim(309500, 311500)
plt.legend(loc='upper right')
plt.show()
fig.savefig('s1.pdf')
